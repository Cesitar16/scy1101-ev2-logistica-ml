# %% [markdown]
# # Análisis Final

# %% [markdown]
# **Objetivo:** integrar hallazgos, resultados, conclusiones y recomendaciones.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Aporte del modelo no supervisado
#
# El modelo K-Means permitió segmentar las entregas en grupos con características similares.
# Aunque este modelo no predice directamente el tiempo de entrega, entrega una visión exploratoria útil para el negocio.
#
# Los clusters pueden interpretarse como perfiles operativos de entregas. Por ejemplo, entregas con mayor distancia, más paradas previas, mayor costo o mayor consumo de combustible pueden pertenecer a grupos distintos.
#
# Esto permite que una empresa logística no solo prediga tiempos, sino también entienda qué tipos de entregas existen dentro de su operación.

# %% [markdown]
# ## Aporte de la optimización
#
# La optimización de hiperparámetros permitió mejorar la configuración del modelo supervisado.
# En vez de elegir valores manualmente, se probaron distintas combinaciones mediante validación cruzada.
#
# Esto fortalece la reproducibilidad del proyecto y permite justificar técnicamente por qué se seleccionó el modelo final.

# %% [markdown]
# ## Conclusión de la parte de Ignacio
#
# La parte no supervisada permitió descubrir patrones ocultos en las entregas, mientras que la optimización permitió mejorar el rendimiento del modelo supervisado.
# Ambas partes aportan al ciclo completo de Machine Learning solicitado en la evaluación: exploración, modelado, evaluación, optimización e interpretación de resultados.

# %% [markdown]
# ## Pendiente de desarrollo
