# %% [markdown]
# # Modelado Supervisado

# %% [markdown]
# **Objetivo:** entrenar modelos de clasificación y/o regresión según el target definido.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Pendiente de desarrollo
